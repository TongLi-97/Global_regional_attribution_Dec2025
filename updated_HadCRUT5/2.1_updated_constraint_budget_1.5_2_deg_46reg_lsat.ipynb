# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import xarray as xr
import numpy as np
from natsort import natsorted
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %%
import sys
original_path = os.getcwd()  
os.chdir(original_path)
function_path = '../functions/'
sys.path.append(function_path)
from smoothing_function import *
from model_analysis_function import *
from analysis_function import *
from Plot_function import *
from ar6_area_weighted_cont_global import *
from f1_0_H_sum_multi_region_constrain import *

# from obs_function import *

# %% [markdown]
# ### Constrain the regional, continent and global land warming

# %% [markdown]
# ### Load the regional, continent and global land data

# %%
path = '../saved_data/'

def load_xr_pickle(filename):
    with open(filename, "rb") as f:
        return pickle.load(f)

obs_all = load_xr_pickle(path + '0.1.HadCRUT5.Tas.anomalies.46AR6regions_7cont_1glob_175years_1850-2024.pkl')

obs_200runs_all = load_xr_pickle(path + '0.2.HadCRUT5.200runs.nonmasked.Tas.anomalies.46AR6regions_7cont_1glob_175years_1850-2024.pkl')

mod_all_his_fu = load_xr_pickle(path + '0.4.Smoothed_His-Fu-ALL.25mods.mean.nonmasked.Tas.anomalies.46AR6regions_7cont_1glob_251years_1850-2100.pkl')

ln_mod_all = load_xr_pickle(path + '0.3.Large_ensembles.320runs.nonmasked.Tas.anomalies.46AR6regions_7cont_1glob_251years_1850-2100.pkl')

mod_45_pseudo = load_xr_pickle(path + '0.5.pseudo-model.15mod.run1-3.nonmasked.Tas.anomalies.46AR6regions_7cont_1glob_176years_1850-2025.pkl')

print_xarray_info(obs_all, obs_200runs_all, mod_all_his_fu, ln_mod_all, mod_45_pseudo)
# Out:
# Array 1:
#   Sizes: Frozen({'year': 175, 'region': 54})
#   Coords: ['realization', 'year', 'region', 'abbrevs', 'names']
#
# Array 2:
#   Sizes: Frozen({'runs': 200, 'year': 175, 'region': 54})
#   Coords: ['runs', 'year', 'region', 'abbrevs', 'names']
#
# Array 3:
#   Sizes: Frozen({'forcing': 1, 'model_name': 25, 'year': 251, 'region': 54})
#   Coords: ['model_name', 'region', 'year', 'abbrevs', 'names', 'forcing']
#
# Array 4:
#   Sizes: Frozen({'model_run': 320, 'year': 251, 'region': 54})
#   Coords: ['year', 'model_run', 'model_name', 'region', 'abbrevs', 'names']
#
# Array 5:
#   Sizes: Frozen({'model_run': 45, 'year': 176, 'region': 54})
#   Coords: ['model_run', 'year', 'model_name', 'region', 'abbrevs', 'names']

# %%
path = '../saved_data/'

tas_obs_200runs = load_xr_pickle(path + 'HadCRUT5.200runs.nonmasked.Tas.anomalies.46AR6regions_7cont_1glob_175years_1850-2025.pkl')

tas_obs_200runs['runs'] = list(range(1, 201))

obs_all_v3 = xr.concat([obs_all, tas_obs_200runs.mean('runs').sel(year = 2025)], dim = 'year')
obs_200runs_all_v3 = xr.concat([obs_200runs_all, tas_obs_200runs.sel(year = 2025)], dim = 'year')

# %%
from f_schemes import *

region_groups = {
    'North and Central America': ['GIC', 'NWN', 'NEN', 'WNA', 'CNA', 'ENA', 'NCA', 'SCA', 'CAR'],
    'South America': ['NWS', 'NSA', 'NES', 'SAM', 'SWS', 'SES', 'SSA'],
    'Europe': ['NEU', 'WCE', 'EEU', 'MED'],
    'Africa': ['SAH', 'WAF', 'CAF', 'NEAF', 'SEAF', 'WSAF', 'ESAF', 'MDG'],
    'Asia': ['RAR', 'WSB', 'ESB', 'RFE', 'WCA', 'ECA', 'TIB', 'EAS', 'ARP', 'SAS'],
    'Australasia': ['SEA', 'NAU', 'CAU', 'EAU', 'SAU', 'NZ'],
    'Antarctica': ['EAN', 'WAN'],
    'Global land': ['LSAT']
}

scheme_reg_lsat = generate_global_regional_target_constraint_pairs(region_groups, global_abbrev='LSAT')

scheme_reg_lsat
# Out:
# [{'target_reg': 'GIC', 'constrain_used_reg': ['GIC', 'LSAT']},
#  {'target_reg': 'NWN', 'constrain_used_reg': ['NWN', 'LSAT']},
#  {'target_reg': 'NEN', 'constrain_used_reg': ['NEN', 'LSAT']},
#  {'target_reg': 'WNA', 'constrain_used_reg': ['WNA', 'LSAT']},
#  {'target_reg': 'CNA', 'constrain_used_reg': ['CNA', 'LSAT']},
#  {'target_reg': 'ENA', 'constrain_used_reg': ['ENA', 'LSAT']},
#  {'target_reg': 'NCA', 'constrain_used_reg': ['NCA', 'LSAT']},
#  {'target_reg': 'SCA', 'constrain_used_reg': ['SCA', 'LSAT']},
#  {'target_reg': 'CAR', 'constrain_used_reg': ['CAR', 'LSAT']},
#  {'target_reg': 'NWS', 'constrain_used_reg': ['NWS', 'LSAT']},
#  {'target_reg': 'NSA', 'constrain_used_reg': ['NSA', 'LSAT']},
#  {'target_reg': 'NES', 'constrain_used_reg': ['NES', 'LSAT']},
#  {'target_reg': 'SAM', 'constrain_used_reg': ['SAM', 'LSAT']},
#  {'target_reg': 'SWS', 'constrain_used_reg': ['SWS', 'LSAT']},
#  {'target_reg': 'SES', 'constrain_used_reg': ['SES', 'LSAT']},
#  {'target_reg': 'SSA', 'constrain_used_reg': ['SSA', 'LSAT']},
#  {'target_reg': 'NEU', 'constrain_used_reg': ['NEU', 'LSAT']},
#  {'target_reg': 'WCE', 'constrain_used_reg': ['WCE', 'LSAT']},
#  {'target_reg': 'EEU', 'constrain_used_reg': ['EEU', 'LSAT']},
#  {'target_reg': 'MED', 'constrain_used_reg': ['MED', 'LSAT']},
#  {'target_reg': 'SAH', 'constrain_used_reg': ['SAH', 'LSAT']},
#  {'target_reg': 'WAF', 'constrain_used_reg': ['WAF', 'LSAT']},
#  {'target_reg': 'CAF', 'constrain_used_reg': ['CAF', 'LSAT']},
#  {'target_reg': 'NEAF', 'constrain_used_reg': ['NEAF', 'LSAT']},
#  {'target_reg': 'SEAF', 'constrain_used_reg': ['SEAF', 'LSAT']},
#  {'target_reg': 'WSAF', 'constrain_used_reg': ['WSAF', 'LSAT']},
#  {'target_reg': 'ESAF', 'constrain_used_reg': ['ESAF', 'LSAT']},
#  {'target_reg': 'MDG', 'constrain_used_reg': ['MDG', 'LSAT']},
#  {'target_reg': 'RAR', 'constrain_used_reg': ['RAR', 'LSAT']},
#  {'target_reg': 'WSB', 'constrain_used_reg': ['WSB', 'LSAT']},
#  {'target_reg': 'ESB', 'constrain_used_reg': ['ESB', 'LSAT']},
#  {'target_reg': 'RFE', 'constrain_used_reg': ['RFE', 'LSAT']},
#  {'target_reg': 'WCA', 'constrain_used_reg': ['WCA', 'LSAT']},
#  {'target_reg': 'ECA', 'constrain_used_reg': ['ECA', 'LSAT']},
#  {'target_reg': 'TIB', 'constrain_used_reg': ['TIB', 'LSAT']},
#  {'target_reg': 'EAS', 'constrain_used_reg': ['EAS', 'LSAT']},
#  {'target_reg': 'ARP', 'constrain_used_reg': ['ARP', 'LSAT']},
#  {'target_reg': 'SAS', 'constrain_used_reg': ['SAS', 'LSAT']},
#  {'target_reg': 'SEA', 'constrain_used_reg': ['SEA', 'LSAT']},
#  {'target_reg': 'NAU', 'constrain_used_reg': ['NAU', 'LSAT']},
#  {'target_reg': 'CAU', 'constrain_used_reg': ['CAU', 'LSAT']},
#  {'target_reg': 'EAU', 'constrain_used_reg': ['EAU', 'LSAT']},
#  {'target_reg': 'SAU', 'constrain_used_reg': ['SAU', 'LSAT']},
#  {'target_reg': 'NZ', 'constrain_used_reg': ['NZ', 'LSAT']},
#  {'target_reg': 'EAN', 'constrain_used_reg': ['EAN', 'LSAT']},
#  {'target_reg': 'WAN', 'constrain_used_reg': ['WAN', 'LSAT']},
#  {'target_reg': 'LSAT', 'constrain_used_reg': ['LSAT', 'LSAT']}]

# %% [markdown]
# ### Constrained warming relative to current year 2025

# %%
#### global_region constraint
mod_all_his_fu_new = xr.concat([mod_all_his_fu.isel(region=slice(0, 46)), mod_all_his_fu.isel(region=53)], dim = 'region')

constrain_func = constrain_sum_reg
obs = obs_all_v3
obs_200runs = obs_200runs_all_v3
ln_mod = ln_mod_all
mod_his = mod_all_his_fu_new
mod_da = mod_all_his_fu_new
obs_ar6 = obs_all_v3
region_names = list(mod_da.names.values)
forcing_list = mod_da.forcing  # xarray.DataArray
his_forcing = ['ALL']
constrain_forcing_names=['ALL']

scheme_pairs =  scheme_reg_lsat

_, _, prior_smooth_ALL_ref2025, post_smooth_ALL_ref2025, obs_adj_ALL_ref2025 = \
    process_all_regions(scheme_pairs, constrain_func, obs, obs_200runs, ln_mod, mod_his, mod_da, obs_ar6, region_names, forcing_list, his_forcing, constrain_forcing_names, 
    reg_id = slice(0, len(region_names)),
    uncertainty_ref_period=(1850, 2025),
    ref_period=(2025, 2026),
    obs_adjust_ref_period=(1961, 2025),
    warming_target_period=(2016, 2025),
    calc_smoothed = True, 
    print_constraint_regions = True)
# Out:
# Processing region 0: Greenland/Iceland
#  Constraining used region 0: ['GIC', 'LSAT']
# Processing region 1: N.W.North-America
#  Constraining used region 1: ['NWN', 'LSAT']
# Processing region 2: N.E.North-America
#  Constraining used region 2: ['NEN', 'LSAT']
# Processing region 3: W.North-America
#  Constraining used region 3: ['WNA', 'LSAT']
# Processing region 4: C.North-America
#  Constraining used region 4: ['CNA', 'LSAT']
# Processing region 5: E.North-America
#  Constraining used region 5: ['ENA', 'LSAT']
# Processing region 6: N.Central-America
#  Constraining used region 6: ['NCA', 'LSAT']
# Processing region 7: S.Central-America
#  Constraining used region 7: ['SCA', 'LSAT']
# Processing region 8: Caribbean
#  Constraining used region 8: ['CAR', 'LSAT']
# Processing region 9: N.W.South-America
#  Constraining used region 9: ['NWS', 'LSAT']
# Processing region 10: N.South-America
#  Constraining used region 10: ['NSA', 'LSAT']
# Processing region 11: N.E.South-America
#  Constraining used region 11: ['NES', 'LSAT']
# Processing region 12: South-American-Monsoon
#  Constraining used region 12: ['SAM', 'LSAT']
# Processing region 13: S.W.South-America
#  Constraining used region 13: ['SWS', 'LSAT']
# Processing region 14: S.E.South-America
#  Constraining used region 14: ['SES', 'LSAT']
# Processing region 15: S.South-America
#  Constraining used region 15: ['SSA', 'LSAT']
# Processing region 16: N.Europe
#  Constraining used region 16: ['NEU', 'LSAT']
# Processing region 17: West&Central-Europe
#  Constraining used region 17: ['WCE', 'LSAT']
# Processing region 18: E.Europe
#  Constraining used region 18: ['EEU', 'LSAT']
# Processing region 19: Mediterranean
#  Constraining used region 19: ['MED', 'LSAT']
# Processing region 20: Sahara
#  Constraining used region 20: ['SAH', 'LSAT']
# Processing region 21: Western-Africa
#  Constraining used region 21: ['WAF', 'LSAT']
# Processing region 22: Central-Africa
#  Constraining used region 22: ['CAF', 'LSAT']
# Processing region 23: N.Eastern-Africa
#  Constraining used region 23: ['NEAF', 'LSAT']
# Processing region 24: S.Eastern-Africa
#  Constraining used region 24: ['SEAF', 'LSAT']
# Processing region 25: W.Southern-Africa
#  Constraining used region 25: ['WSAF', 'LSAT']
# Processing region 26: E.Southern-Africa
#  Constraining used region 26: ['ESAF', 'LSAT']
# Processing region 27: Madagascar
#  Constraining used region 27: ['MDG', 'LSAT']
# Processing region 28: Russian-Arctic
#  Constraining used region 28: ['RAR', 'LSAT']
# Processing region 29: W.Siberia
#  Constraining used region 29: ['WSB', 'LSAT']
# Processing region 30: E.Siberia
#  Constraining used region 30: ['ESB', 'LSAT']
# Processing region 31: Russian-Far-East
#  Constraining used region 31: ['RFE', 'LSAT']
# Processing region 32: W.C.Asia
#  Constraining used region 32: ['WCA', 'LSAT']
# Processing region 33: E.C.Asia
#  Constraining used region 33: ['ECA', 'LSAT']
# Processing region 34: Tibetan-Plateau
#  Constraining used region 34: ['TIB', 'LSAT']
# Processing region 35: E.Asia
#  Constraining used region 35: ['EAS', 'LSAT']
# Processing region 36: Arabian-Peninsula
#  Constraining used region 36: ['ARP', 'LSAT']
# Processing region 37: S.Asia
#  Constraining used region 37: ['SAS', 'LSAT']
# Processing region 38: S.E.Asia
#  Constraining used region 38: ['SEA', 'LSAT']
# Processing region 39: N.Australia
#  Constraining used region 39: ['NAU', 'LSAT']
# Processing region 40: C.Australia
#  Constraining used region 40: ['CAU', 'LSAT']
# Processing region 41: E.Australia
#  Constraining used region 41: ['EAU', 'LSAT']
# Processing region 42: S.Australia
#  Constraining used region 42: ['SAU', 'LSAT']
# Processing region 43: New-Zealand
#  Constraining used region 43: ['NZ', 'LSAT']
# Processing region 44: E.Antarctica
#  Constraining used region 44: ['EAN', 'LSAT']
# Processing region 45: W.Antarctica
#  Constraining used region 45: ['WAN', 'LSAT']
# Processing region 46: Global Land
#  Constraining used region 46: ['LSAT', 'LSAT']

# %% [markdown]
# ### Constrained warming relative to pre-industrial 1850-1900 year

# %%
#### global_region constraint
constrain_func = constrain_sum_reg
obs = obs_all
obs_200runs = obs_200runs_all
ln_mod = ln_mod_all
mod_his = mod_all_his_fu_new
mod_da = mod_all_his_fu_new
obs_ar6 = obs_all
region_names = list(mod_da.names.values)
forcing_list = mod_da.forcing  # xarray.DataArray
his_forcing = ['ALL']
constrain_forcing_names=['ALL']

scheme_pairs =  scheme_reg_lsat

_, _, prior_smooth_ALL_ref1850, post_smooth_ALL_ref1850, obs_adj_ALL_ref1850 = \
    process_all_regions(scheme_pairs, constrain_func, obs, obs_200runs, ln_mod, mod_his, mod_da, obs_ar6, region_names, forcing_list, his_forcing, constrain_forcing_names, 
    reg_id = slice(0, len(region_names)),
    uncertainty_ref_period=(1850, 2025),
    ref_period=(1850, 1900),
    obs_adjust_ref_period=(1961, 2025),
    warming_target_period=(2016, 2025),
    calc_smoothed = True, 
    print_constraint_regions = True)
# Out:
# Processing region 0: Greenland/Iceland
#  Constraining used region 0: ['GIC', 'LSAT']
# Processing region 1: N.W.North-America
#  Constraining used region 1: ['NWN', 'LSAT']
# Processing region 2: N.E.North-America
#  Constraining used region 2: ['NEN', 'LSAT']
# Processing region 3: W.North-America
#  Constraining used region 3: ['WNA', 'LSAT']
# Processing region 4: C.North-America
#  Constraining used region 4: ['CNA', 'LSAT']
# Processing region 5: E.North-America
#  Constraining used region 5: ['ENA', 'LSAT']
# Processing region 6: N.Central-America
#  Constraining used region 6: ['NCA', 'LSAT']
# Processing region 7: S.Central-America
#  Constraining used region 7: ['SCA', 'LSAT']
# Processing region 8: Caribbean
#  Constraining used region 8: ['CAR', 'LSAT']
# Processing region 9: N.W.South-America
#  Constraining used region 9: ['NWS', 'LSAT']
# Processing region 10: N.South-America
#  Constraining used region 10: ['NSA', 'LSAT']
# Processing region 11: N.E.South-America
#  Constraining used region 11: ['NES', 'LSAT']
# Processing region 12: South-American-Monsoon
#  Constraining used region 12: ['SAM', 'LSAT']
# Processing region 13: S.W.South-America
#  Constraining used region 13: ['SWS', 'LSAT']
# Processing region 14: S.E.South-America
#  Constraining used region 14: ['SES', 'LSAT']
# Processing region 15: S.South-America
#  Constraining used region 15: ['SSA', 'LSAT']
# Processing region 16: N.Europe
#  Constraining used region 16: ['NEU', 'LSAT']
# Processing region 17: West&Central-Europe
#  Constraining used region 17: ['WCE', 'LSAT']
# Processing region 18: E.Europe
#  Constraining used region 18: ['EEU', 'LSAT']
# Processing region 19: Mediterranean
#  Constraining used region 19: ['MED', 'LSAT']
# Processing region 20: Sahara
#  Constraining used region 20: ['SAH', 'LSAT']
# Processing region 21: Western-Africa
#  Constraining used region 21: ['WAF', 'LSAT']
# Processing region 22: Central-Africa
#  Constraining used region 22: ['CAF', 'LSAT']
# Processing region 23: N.Eastern-Africa
#  Constraining used region 23: ['NEAF', 'LSAT']
# Processing region 24: S.Eastern-Africa
#  Constraining used region 24: ['SEAF', 'LSAT']
# Processing region 25: W.Southern-Africa
#  Constraining used region 25: ['WSAF', 'LSAT']
# Processing region 26: E.Southern-Africa
#  Constraining used region 26: ['ESAF', 'LSAT']
# Processing region 27: Madagascar
#  Constraining used region 27: ['MDG', 'LSAT']
# Processing region 28: Russian-Arctic
#  Constraining used region 28: ['RAR', 'LSAT']
# Processing region 29: W.Siberia
#  Constraining used region 29: ['WSB', 'LSAT']
# Processing region 30: E.Siberia
#  Constraining used region 30: ['ESB', 'LSAT']
# Processing region 31: Russian-Far-East
#  Constraining used region 31: ['RFE', 'LSAT']
# Processing region 32: W.C.Asia
#  Constraining used region 32: ['WCA', 'LSAT']
# Processing region 33: E.C.Asia
#  Constraining used region 33: ['ECA', 'LSAT']
# Processing region 34: Tibetan-Plateau
#  Constraining used region 34: ['TIB', 'LSAT']
# Processing region 35: E.Asia
#  Constraining used region 35: ['EAS', 'LSAT']
# Processing region 36: Arabian-Peninsula
#  Constraining used region 36: ['ARP', 'LSAT']
# Processing region 37: S.Asia
#  Constraining used region 37: ['SAS', 'LSAT']
# Processing region 38: S.E.Asia
#  Constraining used region 38: ['SEA', 'LSAT']
# Processing region 39: N.Australia
#  Constraining used region 39: ['NAU', 'LSAT']
# Processing region 40: C.Australia
#  Constraining used region 40: ['CAU', 'LSAT']
# Processing region 41: E.Australia
#  Constraining used region 41: ['EAU', 'LSAT']
# Processing region 42: S.Australia
#  Constraining used region 42: ['SAU', 'LSAT']
# Processing region 43: New-Zealand
#  Constraining used region 43: ['NZ', 'LSAT']
# Processing region 44: E.Antarctica
#  Constraining used region 44: ['EAN', 'LSAT']
# Processing region 45: W.Antarctica
#  Constraining used region 45: ['WAN', 'LSAT']
# Processing region 46: Global Land
#  Constraining used region 46: ['LSAT', 'LSAT']

# %% [markdown]
# ### Save results to files

# %%
save_path = './saved_data/'

name = '2.2_constrained_46reg_lsat_smoothed_warming_ref2025_1850-2100.pkl'

with open(save_path + name, 'wb') as wi:
	pickle.dump(post_smooth_ALL_ref2025, wi)

name = '2.3_constrained_46reg_lsat_smoothed_warming_ref1850_1850-2100.pkl'

with open(save_path + name, 'wb') as wi:
	pickle.dump(post_smooth_ALL_ref1850, wi)

name = '2.3_adjust_obs_warming_ref1850_1850-2100.pkl'

with open(save_path + name, 'wb') as wi:
	pickle.dump(obs_adj_ALL_ref1850, wi)


name = '2.2_prior_46reg_smoothed_warming_ref2025_1850-2100.pkl'

with open(save_path + name, 'wb') as wi:
	pickle.dump(prior_smooth_ALL_ref2025, wi)

name = '2.3_prior_46reg_smoothed_warming_ref1850_1850-2100.pkl'

with open(save_path + name, 'wb') as wi:
	pickle.dump(prior_smooth_ALL_ref1850, wi)
